# %%
from data_prep import load_data, prepare_features_and_target, get_preprocessor

df = load_data("../data/raw/WA_Fn-UseC_-Telco-Customer-Churn.csv")
X, y = prepare_features_and_target(df)
preprocessor = get_preprocessor(X)

X.shape, y.shape
# Out:
# ((7043, 19), (7043,))

# %%
from evaluate import campaign_threshold_analysis

results = campaign_threshold_analysis(
    data_path="../data/raw/WA_Fn-UseC_-Telco-Customer-Churn.csv",
    model_path="../models/churn_pipeline_logreg.joblib",
    target_fraction=0.20
)

results
# Out:
# /Users/aishwarya/Desktop/marketing-customer-churn-ml-system/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/aishwarya/Desktop/marketing-customer-churn-ml-system/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/aishwarya/Desktop/marketing-customer-churn-ml-system/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# {'threshold': np.float64(0.753096503751539),
#  'target_fraction': 0.2,
#  'precision': np.float64(0.6595744680851063),
#  'recall': np.float64(0.49732620320855614),
#  'customers_targeted': 282,
#  'actual_churners_captured': 186}
